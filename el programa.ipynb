# %% [markdown]
# <img src="notebooks_y_mas/Imagenes/el programa.jpg" alt="Imagen creada con inteligencia artificial y editada con Microsoft Paint" style="border-radius: 15px; width: 75%;">
#
# *Imagen creada con inteligencia artificial*

# %% [markdown]
# ## **INTRODUCCIÓN**
# >
# >**Este es "el programa". Con este notebook trataremos de resolver lo que se planteó en la idea de negocio.**
# >
# >**Cuando se ejecute la segunda celda, aparecerá una ventana en la que deberás introducir la clave de la emoción que consideres adecuada para el momento. Las claves se indicarán en una impresión. En caso de que, por un error, se ingrese algo distinto a la clave de la emoción, el programa te pedirá que lo repitas. Una vez ingresada la clave correcta, aparecerá la foto de uno de los sujetos a estudiar, con toda la información impresa sobre la fotografía.**

# %% [markdown]
# ## **CARGAMOS NUESTRA FUNCION**

# %%
import sys
import os
ruta_notebooks_y_mas = os.path.join(os.getcwd(), 'notebooks_y_mas')
if ruta_notebooks_y_mas not in sys.path:
    sys.path.append(ruta_notebooks_y_mas)
from gvatilo import *
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## **USAR EL PROGRAMA**

# %%
while True:
    try:
        print("Por favor, introduce el código de la expresión adecuada:")
        print("0: 'Enfado', 1: 'Asco', 2: 'Miedo', 3: 'Felicidad', 4: 'Tristeza', 5: 'Sorpresa', 6: 'Neutral'")
        num = int(input("Tu elección (0-6): "))
        if 0 <= num <= 6:
            vigilante(num)
            break  # Sale del bucle si el número es válido
        else:
            print("Error: Recuerda que solo puedes introducir números del 0 al 6.")
    except ValueError:
        print("Error: Debes ingresar un número entero del 0 al 6.")
# Out:
# Por favor, introduce el código de la expresión adecuada:
# 0: 'Enfado', 1: 'Asco', 2: 'Miedo', 3: 'Felicidad', 4: 'Tristeza', 5: 'Sorpresa', 6: 'Neutral'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %% [markdown]
# ## **AUTOCRíTICA**
#
# El programa tiene una tasa de aciertos ligeramente superior al 50%, considerando que se ha usado una colección de fotografías que incluye una cantidad considerable de imágenes generadas por inteligencia artificial, con gestos muy exagerados. Además, algunos de estos “fallos” son algo discutibles, ya que una cara de sorpresa puede ser considerada como una cara de felicidad o incluso de miedo, según el gesto.
#
# Teniendo en cuenta que si el modelo funcionase por aleatoriedad, la tasa de aciertos esperada sería de aproximadamente el 14.29%, y considerando que la tasa de acierto supera, más o menos, el 50%, no contra test o validación sino con otra colección de fotografías diferente, las cuales incluso están en otro formato, podemos decir que hemos multiplicado por 3.5 las posibilidades de acierto.
#
# En la búsqueda del modelo, tuve en cuenta que no hubiera sobreajuste (overfitting). Aunque entrené modelos con mayor precisión, en las gráficas de entrenamiento se captaba sobreajuste. Por lo tanto, decidí buscar el menor sobreajuste, incluso en detrimento de la precisión.
#
# ¿Es mejorable? Sí, es muy mejorable, bastante mejorable de hecho, pero teniendo en cuenta que no ha sido un trabajo grupal y se ha hecho con un “ordenador normal”, algunos modelos estuvieron corriendo más de 20 horas, podemos considerar el resultado aceptable.
